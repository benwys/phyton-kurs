# %% [markdown]
# <a href="https://colab.research.google.com/github/benwys/phyton-kurs/blob/main/sierpinski_triangle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 10000

#initialize x and y vectors
sx = np.zeros(N)
sy = np.zeros(N)

for i in range(1,N):
  # generate a random nuber {1,2,3}
  k = np.random.randint(1,4)
  #update the x and y points
  sx[i] = sx[i-1]/2 + k-1
  sy[i] = sy[i-1]/2
  if k==2:
    sy[i] += 2

plt.plot(sx,sy,'k.', markersize=1)
plt.title('Sierpinski triangle')
plt.axis('off')
plt.show()

# %% [markdown]
# # for i in {1,2,..,N}
# # k    <- random in {1,2,3}
# #  x(i) <- .5x(i-1) + k-1
# #  y(i) <- .5y(i-1)
# #  if k is 2, y(i) <- y+2
